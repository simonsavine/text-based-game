# %% [markdown]
# <a href="https://colab.research.google.com/github/simonsavine/Side-projects/blob/main/Snake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pygame

pygame.init()

class Snake:

  def __init__(self, snakex, snakey):
    self.snakex = snakex
    self.snakey = snakey

class Apple:

  def __init__(self, applex, appley):
    self.applex = applex
    self.appley = appley

class GameLoop:

  def __init__(self, width, height):
    self.width = width
    self.height = height

  def playerInput():
    moveup = pygame.key.get_pressed("W")
    moveleft = pygame.key.get_pressed("A")
    movedown = pygame.key.get_pressed("S")
    moveright = pygame.key.get_pressed("D")
    move = pygame.key.get_pressed("return")

  def points(apples, applepoints):
    return apples * applepoints


  def board_matrix():
    # Intialize matrix

    matrix =


  def render():
    print("Height: ", self.height)
    print("Width: ", self.width)

    board = self.board_matrix()

    #for row in matrix:


game = GameLoop(10,20)
game.render()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1367/3248112370.py in <cell line: 0>()
#      38
#      39 game = GameLoop(10,20)
# ---> 40 game.render()
#
# TypeError: GameLoop.render() takes 0 positional arguments but 1 was given

# %%
import os

print(os.get_terminal_size())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_6671/246439376.py in <cell line: 0>()
#       1 import os
#       2
# ----> 3 print(os.get_terminal_size())
#
# OSError: [Errno 25] Inappropriate ioctl for device
