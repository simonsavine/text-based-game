# %% [markdown]
# <a href="https://colab.research.google.com/github/simonsavine/text-based-game/blob/main/ASCII_Art_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import math


# Part 1, user input:

flag = True
while flag:
  try:
    filename = input("Input your image file name: ")
    img = Image.open(filename)
    width, height = img.size
    plt.imshow(img)
    flag = False

  except FileNotFoundError:
        flag = True

# Change width and height for your specific terminal:

width = 200
aspect_ratio = img.height / img.width
height = int(width * aspect_ratio * 0.45)
img = img.resize((width, height))

width, height = img.size

# Accumulate RGB values of image in pixel matrix:

pixel_matrix = np.array(img)

# Convert RGB to single brightness numbers using mean:

RGB_arr = 0.21 * pixel_matrix[:, : , 0] + 0.72 * pixel_matrix[:, : , 1] + 0.07 * pixel_matrix[:, : , 2]

# Convert brightness to ASCII:

# Remove comment for more character nuances:

#characters = "`^\",:;Il!i~+_-?][}{1)(|\\/tfjrxnuvczXYUJCLQ0OZmwqpdbkhao*#MW&8%B@$"
characters = " .:-=+*#%@"
characters = characters[::-1]

ASCII_arr = []

for rgbval in RGB_arr.flatten():
  charNum = math.floor(rgbval / 255 * len(characters))
  ASCII_arr.append(characters[charNum])

print("Here is your image in beautiful ASCII art:")

for row in range(0, len(ASCII_arr), width):
  line = ASCII_arr[row:row+width]
  print("".join(line))
# Out:
#      <input type="file" id="files-db63d033-f0f4-4cd7-b8a6-75b1cece9515" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db63d033-f0f4-4cd7-b8a6-75b1cece9515">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
